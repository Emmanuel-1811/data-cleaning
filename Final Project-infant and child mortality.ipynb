# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Get a list of African countries from pycountry
import pycountry
import random
import numpy as np

# %%
# Load datasets
health_coverage = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\8. health-protection-coverage.csv")
vaccination_coverage = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\cleaned_7_global_vaccination_coverage.csv")
skilled_births = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\6. births-attended-by-health-staff-sdgs.csv")
maternal_deaths = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\5. number-of-maternal-deaths-by-region.csv")
child_mortality_income = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\3. child-mortality-by-income-level-of-country.csv")
infant_deaths = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\2. number-of-infant-deaths-unwpp.csv")
youth_mortality = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\1. youth-mortality-rate.csv")
causes_of_death = pd.read_csv(r"C:\Users\My PC\Desktop\Infant Mortality Rate\4. Distribution of Causes of Death among Children Aged less than 5 years.csv")

# %%
#filter african countries data from datasets
print(health_coverage.columns)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Share of population covered by health insurance (ILO (2014))'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
health_coverage_africa = health_coverage[health_coverage['Entity'].isin(african_countries)]
df1 = health_coverage_africa
df1.shape
# Out:
# (36, 4)

# %%
df1
# Out:
#                        Entity Code  Year  \
# 1                     Algeria  DZA  2005
# 3                      Angola  AGO  2010
# 18                      Benin  BEN  2009
# 25               Burkina Faso  BFA  2010
# 26                    Burundi  BDI  2009
# 28                   Cameroon  CMR  2009
# 30   Central African Republic  CAF  2008
# 42                   Djibouti  DJI  2006
# 46                      Egypt  EGY  2008
# 49                   Eswatini  SWZ  2006
# 53                      Gabon  GAB  2010
# 54                     Gambia  GMB  2011
# 57                      Ghana  GHA  2010
# 61                     Guinea  GIN  2010
# 62              Guinea-Bissau  GNB  2009
# 79                      Kenya  KEN  2009
# 85                    Lesotho  LSO  2009
# 89                 Madagascar  MDG  2009
# 92                       Mali  MLI  2008
# 94                 Mauritania  MRT  2009
# 95                  Mauritius  MUS  2010
# 100                   Morocco  MAR  2007
# ...

# %%
# Drop the 'Year' column
df1 = df1.drop(columns=["Year"])
df1
# Out:
#                        Entity Code  \
# 1                     Algeria  DZA
# 3                      Angola  AGO
# 18                      Benin  BEN
# 25               Burkina Faso  BFA
# 26                    Burundi  BDI
# 28                   Cameroon  CMR
# 30   Central African Republic  CAF
# 42                   Djibouti  DJI
# 46                      Egypt  EGY
# 49                   Eswatini  SWZ
# 53                      Gabon  GAB
# 54                     Gambia  GMB
# 57                      Ghana  GHA
# 61                     Guinea  GIN
# 62              Guinea-Bissau  GNB
# 79                      Kenya  KEN
# 85                    Lesotho  LSO
# 89                 Madagascar  MDG
# 92                       Mali  MLI
# 94                 Mauritania  MRT
# 95                  Mauritius  MUS
# 100                   Morocco  MAR
# 101                   Namibia  NAM
# 106                     Niger  NER
# 107                   Nigeria  NGA
# ...

# %%
df1.describe()
# Out:
#        Share of population covered by health insurance (ILO (2014))
# count                                          36.000000
# mean                                           28.738889
# std                                            34.364353
# min                                             0.000000
# 25%                                             2.075000
# 50%                                             8.700000
# 75%                                            44.500000
# max                                           100.000000

# %%
# check for missing values
df1.isnull().sum()
# Out:
# Entity                                                          0
# Code                                                            0
# Share of population covered by health insurance (ILO (2014))    0
# dtype: int64

# %%
# check for duplicate values
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Generate Random Colors for Each Country
random_colors = {category: f"#{random.randint(0, 0xFFFFFF):06x}" for category in df1['Entity']}

# Plot Bar Chart
plt.figure(figsize=(10, 8))
for index, row in df1.iterrows():
    plt.bar(row['Entity'], row['Share of population covered by health insurance (ILO (2014))'], color=random_colors[row['Entity']], label=row['Entity'])

# Entity Vs Share of Population covered by health insurance
plt.xlabel('Entity')
plt.ylabel('Share of population covered by health insurance (ILO (2014)) %')
plt.title('Health Insurance Coverage of African Countries')
plt.xticks(rotation=90)

# Create Color Key
#handles = [plt.Rectangle((0, 0), 1, 1, color=color) for color in random_colors.values()]
#labels = random_colors.keys()
#plt.legend(handles, labels, title="Color Key", bbox_to_anchor=(1.05, 1), loc='upper left')

# Display the plot
plt.tight_layout()
plt.show()

# %%
#The dataset "vaccination_coverage" contained 14 columns with a mix of numerical and categorical data. 
# Several columns have missing values, particularly for immunization rates. 
# The dataset was cleaned with the following changes:
# 1.  Dropped Columns: Removed columns with more than 75% missing values (IPV1, PCV3, RotaC, YFV).
# 2.  Missing Values: Filled remaining missing values using the median for numerical columns.
# 3.  Duplicates: Removed duplicate rows (if any existed).
# 4.  Range Verification: Ensured all percentage values are clipped between 0 and 100.
# The cleaned dataset now contains 10 columns and 7897 rows, and ready for analysis.

# %%
print(vaccination_coverage.columns)
# Out:
# Index(['Entity', 'Code', 'Year', 'BCG (% of one-year-olds immunized)',
#        'HepB3 (% of one-year-olds immunized)',
#        'Hib3 (% of one-year-olds immunized)',
#        'MCV1 (% of one-year-olds immunized)',
#        'Pol3 (% of one-year-olds immunized)',
#        'Pol3 (% of one-year-olds immunized).1',
#        'DTP3 (% of one-year-olds immunized)'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
vaccination_coverage_africa = vaccination_coverage[vaccination_coverage['Entity'].isin(african_countries)]
cleaned_df2 = vaccination_coverage_africa
cleaned_df2
# Out:
#         Entity Code  Year  BCG (% of one-year-olds immunized)  \
# 126    Algeria  DZA  1985                                  86
# 127    Algeria  DZA  1986                                  88
# 128    Algeria  DZA  1987                                  93
# 129    Algeria  DZA  1988                                  96
# 130    Algeria  DZA  1989                                  96
# ...        ...  ...   ...                                 ...
# 7892  Zimbabwe  ZWE  2017                                  95
# 7893  Zimbabwe  ZWE  2018                                  95
# 7894  Zimbabwe  ZWE  2019                                  95
# 7895  Zimbabwe  ZWE  2020                                  88
# 7896  Zimbabwe  ZWE  2021                                  88
#
#       HepB3 (% of one-year-olds immunized)  \
# 126                                     91
# 127                                     91
# 128                                     91
# ...

# %%
cleaned_df2.describe()
# Out:
#               Year  BCG (% of one-year-olds immunized)  \
# count  1941.000000                         1941.000000
# mean   2001.657393                           79.912931
# std      11.703669                           20.764639
# min    1980.000000                            2.000000
# 25%    1992.000000                           72.000000
# 50%    2002.000000                           88.000000
# 75%    2012.000000                           95.000000
# max    2021.000000                           99.000000
#
#        HepB3 (% of one-year-olds immunized)  \
# count                           1941.000000
# mean                              85.897991
# std                               13.496158
# min                                1.000000
# 25%                               87.000000
# 50%                               91.000000
# 75%                               91.000000
# max                               99.000000
#
#        Hib3 (% of one-year-olds immunized)  \
# ...

# %%
# check for missing values
cleaned_df2.isnull().sum()
# Out:
# Entity                                   0
# Code                                     0
# Year                                     0
# BCG (% of one-year-olds immunized)       0
# HepB3 (% of one-year-olds immunized)     0
# Hib3 (% of one-year-olds immunized)      0
# MCV1 (% of one-year-olds immunized)      0
# Pol3 (% of one-year-olds immunized)      0
# Pol3 (% of one-year-olds immunized).1    0
# DTP3 (% of one-year-olds immunized)      0
# dtype: int64

# %%
# check for duplicate values
cleaned_df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Select numeric columns for mean calculation
numeric_data = cleaned_df2.select_dtypes(include=["number"])

# Group by 'Entity' and calculate mean of numeric columns
grouped_df2 = cleaned_df2.groupby("Entity")[numeric_data.columns].mean()

# %%
# Drop the 'Year' column
grouped_df2 = grouped_df2.drop(columns=["Year"])
grouped_df2
# Out:
#                           BCG (% of one-year-olds immunized)  \
# Entity
# Algeria                                            96.390244
# Angola                                             56.666667
# Benin                                              83.810811
# Botswana                                           96.952381
# Burkina Faso                                       86.378378
# Burundi                                            84.243902
# Cameroon                                           72.682927
# Central African Republic                           63.785714
# Chad                                               46.717949
# Comoros                                            84.342105
# Congo                                              76.738095
# Djibouti                                           65.350000
# Egypt                                              88.619048
# Equatorial Guinea                                  76.918919
# ...

# %%
print(skilled_births.columns)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Births attended by skilled health staff (% of total)'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
skilled_births_africa = skilled_births[skilled_births['Entity'].isin(african_countries)]
df3 = skilled_births_africa
df3
# Out:
#         Entity Code  Year  \
# 32     Algeria  DZA  1992
# 33     Algeria  DZA  2000
# 34     Algeria  DZA  2002
# 35     Algeria  DZA  2006
# 36     Algeria  DZA  2013
# ...        ...  ...   ...
# 2980  Zimbabwe  ZWE  2009
# 2981  Zimbabwe  ZWE  2011
# 2982  Zimbabwe  ZWE  2014
# 2983  Zimbabwe  ZWE  2015
# 2984  Zimbabwe  ZWE  2019
#
#       Births attended by skilled health staff (% of total)
# 32                                                 76.5
# 33                                                 92.0
# 34                                                 95.9
# 35                                                 95.2
# 36                                                 96.6
# ...                                                 ...
# 2980                                               60.2
# 2981                                               66.2
# 2982                                               80.0
# 2983                                               78.1
# ...

# %%
df3.describe()
# Out:
#               Year  Births attended by skilled health staff (% of total)
# count   381.000000                                         381.000000
# mean   2005.503937                                          62.348294
# std       8.723116                                          25.909046
# min    1984.000000                                           5.000000
# 25%    2000.000000                                          43.700000
# 50%    2006.000000                                          60.200000
# 75%    2013.000000                                          85.500000
# max    2021.000000                                         100.000000

# %%
# check for missing values
df3.isnull().sum()
# Out:
# Entity                                                  0
# Code                                                    0
# Year                                                    0
# Births attended by skilled health staff (% of total)    0
# dtype: int64

# %%
# check for duplicate values
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Select numeric columns for mean calculation
numeric_data = df3.select_dtypes(include=["number"])

# Group by 'Entity' and calculate mean of numeric columns
grouped_df3 = df3.groupby("Entity")[numeric_data.columns].mean()
grouped_df3
# Out:
#                                  Year  \
# Entity
# Algeria                   2005.333333
# Angola                    2005.000000
# Benin                     2007.428571
# Botswana                  2006.850000
# Burkina Faso              2004.333333
# Burundi                   2005.166667
# Cameroon                  2005.250000
# Central African Republic  2006.714286
# Chad                      2007.500000
# Comoros                   2002.666667
# Congo                     2010.666667
# Djibouti                  2007.000000
# Egypt                     1998.461538
# Equatorial Guinea         2001.666667
# Eritrea                   2000.750000
# Eswatini                  2004.500000
# Ethiopia                  2008.888889
# Gabon                     2004.333333
# Gambia                    2008.142857
# Ghana                     2004.307692
# Guinea                    2006.666667
# Guinea-Bissau             2007.333333
# Kenya                     2002.750000
# ...

# %%
# Drop the 'Year' column
grouped_df3 = grouped_df3.drop(columns=["Year"])
grouped_df3
# Out:
#                           Births attended by skilled health staff (% of total)
# Entity
# Algeria                                                           92.500000
# Angola                                                            41.675000
# Benin                                                             74.971429
# Botswana                                                          96.390000
# Burkina Faso                                                      44.400000
# Burundi                                                           49.983333
# Cameroon                                                          61.200000
# Central African Republic                                          40.957143
# Chad                                                              20.016667
# Comoros                                                           65.200000
# Congo                                                             68.500000
# ...

# %%
print(maternal_deaths.columns)
# Out:
# Index(['Entity', 'Code', 'Year', 'Estimated maternal deaths',
#        '959828-annotations'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
maternal_deaths_africa = maternal_deaths[maternal_deaths['Entity'].isin(african_countries)]
df4 = maternal_deaths_africa
df4.describe()
# Out:
#               Year  Estimated maternal deaths
# count  1800.000000                1800.000000
# mean   2002.500000                3900.187826
# std      10.391182                9744.897282
# min    1985.000000                   0.061462
# 25%    1993.750000                 346.264430
# 50%    2002.500000                1682.867600
# 75%    2011.250000                3904.089750
# max    2020.000000               86380.270000

# %%
df4
# Out:
#         Entity Code  Year  Estimated maternal deaths 959828-annotations
# 108    Algeria  DZA  1985                  2187.8162                NaN
# 109    Algeria  DZA  1986                  2024.1606                NaN
# 110    Algeria  DZA  1987                  1966.3341                NaN
# 111    Algeria  DZA  1988                  1822.9799                NaN
# 112    Algeria  DZA  1989                  1744.9213                NaN
# ...        ...  ...   ...                        ...                ...
# 7051  Zimbabwe  ZWE  2016                  1918.8360                NaN
# 7052  Zimbabwe  ZWE  2017                  1762.2927                NaN
# 7053  Zimbabwe  ZWE  2018                  1735.1570                NaN
# 7054  Zimbabwe  ZWE  2019                  1906.9050                NaN
# 7055  Zimbabwe  ZWE  2020                  1733.8484                NaN
#
# [1800 rows x 5 columns]

# %%
# check for missing values
df4.isnull().sum()
# Out:
# Entity                          0
# Code                            0
# Year                            0
# Estimated maternal deaths       0
# 959828-annotations           1800
# dtype: int64

# %%
# drop column with NaN value
cleaned_df4 = df4.dropna(axis=1)
cleaned_df4
# Out:
#         Entity Code  Year  Estimated maternal deaths
# 108    Algeria  DZA  1985                  2187.8162
# 109    Algeria  DZA  1986                  2024.1606
# 110    Algeria  DZA  1987                  1966.3341
# 111    Algeria  DZA  1988                  1822.9799
# 112    Algeria  DZA  1989                  1744.9213
# ...        ...  ...   ...                        ...
# 7051  Zimbabwe  ZWE  2016                  1918.8360
# 7052  Zimbabwe  ZWE  2017                  1762.2927
# 7053  Zimbabwe  ZWE  2018                  1735.1570
# 7054  Zimbabwe  ZWE  2019                  1906.9050
# 7055  Zimbabwe  ZWE  2020                  1733.8484
#
# [1800 rows x 4 columns]

# %%
# check for duplicate values
cleaned_df4.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Select numeric columns for mean calculation
numeric_data = cleaned_df4.select_dtypes(include=["number"])

# Group by 'Entity' and calculate mean of numeric columns
grouped_df4 = cleaned_df4.groupby("Entity")[numeric_data.columns].mean()
grouped_df4
# Out:
#                             Year  Estimated maternal deaths
# Entity
# Algeria                   2002.5                1194.778581
# Angola                    2002.5                5215.113211
# Benin                     2002.5                1794.027575
# Botswana                  2002.5                 100.813849
# Burkina Faso              2002.5                2713.475461
# Burundi                   2002.5                2757.348250
# Cameroon                  2002.5                3872.012369
# Central African Republic  2002.5                1799.042475
# Chad                      2002.5                5926.017747
# Comoros                   2002.5                  82.507625
# Congo                     2002.5                 695.709449
# Djibouti                  2002.5                 101.862779
# Egypt                     2002.5                1451.482776
# Equatorial Guinea         2002.5                 144.299106
# ...

# %%
# Drop the 'Year' column
grouped_df4 = grouped_df4.drop(columns=["Year"])
grouped_df4
# Out:
#                           Estimated maternal deaths
# Entity
# Algeria                                 1194.778581
# Angola                                  5215.113211
# Benin                                   1794.027575
# Botswana                                 100.813849
# Burkina Faso                            2713.475461
# Burundi                                 2757.348250
# Cameroon                                3872.012369
# Central African Republic                1799.042475
# Chad                                    5926.017747
# Comoros                                   82.507625
# Congo                                    695.709449
# Djibouti                                 101.862779
# Egypt                                   1451.482776
# Equatorial Guinea                        144.299106
# Eritrea                                  700.793202
# Eswatini                                 161.384561
# Ethiopia                               23616.765306
# ...

# %%
print(child_mortality_income.columns)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
child_mortality_income_africa = child_mortality_income[child_mortality_income['Entity'].isin(african_countries)]
df5 = child_mortality_income_africa
df5.describe()
# Out:
#               Year  \
# count  3244.000000
# mean   1988.941739
# std      20.486166
# min    1932.000000
# 25%    1973.000000
# 50%    1990.000000
# 75%    2006.000000
# max    2022.000000
#
#        Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births
# count                                        3244.000000
# mean                                           15.494184
# std                                             9.174961
# min                                             1.033715
# 25%                                             8.195825
# 50%                                            13.954508
# 75%                                            21.724261
# max                                            42.630410

# %%
# check for missing values
df5.isnull().sum()
# Out:
# Entity                                                                                                                                          0
# Code                                                                                                                                            0
# Year                                                                                                                                            0
# Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births    0
# dtype: int64

# %%
# check for duplicate values
df5.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Select numeric columns for mean calculation
numeric_data = df5.select_dtypes(include=["number"])

# Group by 'Entity' and calculate mean of numeric columns
grouped_df5 = df5.groupby("Entity")[numeric_data.columns].mean()
grouped_df5
# Out:
#                             Year  \
# Entity
# Algeria                   1988.0
# Angola                    2001.0
# Benin                     1983.5
# Botswana                  1988.0
# Burkina Faso              1983.0
# Burundi                   1993.0
# Cameroon                  1987.5
# Central African Republic  1990.5
# Chad                      1997.0
# Comoros                   1996.0
# Congo                     1983.0
# Djibouti                  1999.0
# Egypt                     1988.5
# Equatorial Guinea         2002.0
# Eritrea                   1998.0
# Eswatini                  1985.5
# Ethiopia                  1994.0
# Gabon                     1983.0
# Gambia                    1989.0
# Ghana                     1977.0
# Guinea                    1979.5
# Guinea-Bissau             2003.5
# Kenya                     1987.0
# Lesotho                   1987.0
# Liberia                   1988.0
# Libya                     1989.0
# Madagascar                1995.0
# ...

# %%
# Drop the 'Year' column
grouped_df5 = grouped_df5.drop(columns=["Year"])
grouped_df5
# Out:
#                           Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births
# Entity
# Algeria                                                           11.593816
# Angola                                                            16.985022
# Benin                                                             20.974372
# Botswana                                                           8.919949
# Burkina Faso                                                      24.095998
# Burundi                                                           16.478818
# Cameroon                                                          17.327769
# Central African Republic                                          17.816088
# Chad                                                              18.761423
# Comoros                                                           11.946566
# ...

# %%
print(infant_deaths.columns)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Sex: all - Age: 0 - Variant: estimates'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
infant_deaths_africa = infant_deaths[infant_deaths['Entity'].isin(african_countries)]
df6 = infant_deaths_africa
df6.describe()
# Out:
#               Year  Deaths - Sex: all - Age: 0 - Variant: estimates
# count  3700.000000                                      3700.000000
# mean   1986.500000                                     41448.596210
# std      21.362896                                     75796.695139
# min    1950.000000                                        16.000000
# 25%    1968.000000                                      4127.000000
# 50%    1986.500000                                     23052.000000
# 75%    2005.000000                                     47756.750000
# max    2023.000000                                    608109.000000

# %%
# check for missing values
df6.isnull().sum()
# Out:
# Entity                                             0
# Code                                               0
# Year                                               0
# Deaths - Sex: all - Age: 0 - Variant: estimates    0
# dtype: int64

# %%
# check for duplicate values
df6.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Select numeric columns for mean calculation
numeric_data = df6.select_dtypes(include=["number"])

# Group by 'Entity' and calculate mean of numeric columns
grouped_df6 = df6.groupby("Entity")[numeric_data.columns].mean()
grouped_df6
# Out:
#                             Year  \
# Entity
# Algeria                   1986.5
# Angola                    1986.5
# Benin                     1986.5
# Botswana                  1986.5
# Burkina Faso              1986.5
# Burundi                   1986.5
# Cameroon                  1986.5
# Central African Republic  1986.5
# Chad                      1986.5
# Comoros                   1986.5
# Congo                     1986.5
# Djibouti                  1986.5
# Egypt                     1986.5
# Equatorial Guinea         1986.5
# Eritrea                   1986.5
# Eswatini                  1986.5
# Ethiopia                  1986.5
# Gabon                     1986.5
# Gambia                    1986.5
# Ghana                     1986.5
# Guinea                    1986.5
# Guinea-Bissau             1986.5
# Kenya                     1986.5
# Lesotho                   1986.5
# Liberia                   1986.5
# Libya                     1986.5
# Madagascar                1986.5
# ...

# %%
# Drop the 'Year' column
grouped_df6 = grouped_df6.drop(columns = ["Year"])
grouped_df6
# Out:
#                           Deaths - Sex: all - Age: 0 - Variant: estimates
# Entity
# Algeria                                                      54840.756743
# Angola                                                       66899.999946
# Benin                                                        23966.891892
# Botswana                                                      2212.554054
# Burkina Faso                                                 44195.162162
# Burundi                                                      23593.770270
# Cameroon                                                     42800.148676
# Central African Republic                                     15751.635135
# Chad                                                         38141.797297
# Comoros                                                       1510.743244
# Congo                                                         5911.689189
# Djibouti                                                      1092.432432
# ...

# %%
print(youth_mortality.columns)
# Out:
# Index(['Entity', 'Code', 'Year', 'Under-fifteen mortality rate'], dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
youth_mortality_africa = youth_mortality[youth_mortality['Entity'].isin(african_countries)]
df7 = youth_mortality_africa
df7
# Out:
#          Entity Code  Year  Under-fifteen mortality rate
# 112     Algeria  DZA  1979                     18.178753
# 113     Algeria  DZA  1980                     16.790104
# 114     Algeria  DZA  1981                     15.191734
# 115     Algeria  DZA  1982                     13.394593
# 116     Algeria  DZA  1983                     11.594862
# ...         ...  ...   ...                           ...
# 10510  Zimbabwe  ZWE  2018                      6.515447
# 10511  Zimbabwe  ZWE  2019                      6.387253
# 10512  Zimbabwe  ZWE  2020                      6.259883
# 10513  Zimbabwe  ZWE  2021                      5.999933
# 10514  Zimbabwe  ZWE  2022                      5.834957
#
# [2246 rows x 4 columns]

# %%
# check for missing values
df7.isnull().sum()
# Out:
# Entity                          0
# Code                            0
# Year                            0
# Under-fifteen mortality rate    0
# dtype: int64

# %%
# check for duplicate values
df7.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Select numeric columns for mean calculation
numeric_data = df7.select_dtypes(include=["number"])

# Group by 'Entity' and calculate mean of numeric columns
grouped_df7 = df7.groupby("Entity")[numeric_data.columns].mean()
grouped_df7
# Out:
#                             Year  Under-fifteen mortality rate
# Entity
# Algeria                   2000.5                      5.744129
# Angola                    2006.0                     17.919686
# Benin                     1996.5                     18.852082
# Botswana                  2001.0                      7.229754
# Burkina Faso              2002.0                     18.195194
# Burundi                   1995.0                     19.600290
# Cameroon                  1994.5                     16.991529
# Central African Republic  2002.5                     17.294431
# Chad                      2004.0                     19.691660
# Comoros                   2003.5                     10.053682
# Congo                     2006.0                      9.270731
# Djibouti                  2006.0                     10.239176
# Egypt                     1995.5                     10.144821
# Equatorial Guinea         2006.0                     15.049275
# ...

# %%
# Drop the 'Year' column
grouped_df7 = grouped_df7.drop(columns = ["Year"])
grouped_df7
# Out:
#                           Under-fifteen mortality rate
# Entity
# Algeria                                       5.744129
# Angola                                       17.919686
# Benin                                        18.852082
# Botswana                                      7.229754
# Burkina Faso                                 18.195194
# Burundi                                      19.600290
# Cameroon                                     16.991529
# Central African Republic                     17.294431
# Chad                                         19.691660
# Comoros                                      10.053682
# Congo                                         9.270731
# Djibouti                                     10.239176
# Egypt                                        10.144821
# Equatorial Guinea                            15.049275
# Eritrea                                      11.076380
# Eswatini                                      9.605401
# ...

# %%
print(causes_of_death.columns)
# Out:
# Index(['IndicatorCode', 'Indicator', 'ValueType', 'ParentLocationCode',
#        'ParentLocation', 'Location type', 'SpatialDimValueCode', 'Location',
#        'Period type', 'Period', 'IsLatestYear', 'Dim1 type', 'Dim1',
#        'Dim1ValueCode', 'Dim2 type', 'Dim2', 'Dim2ValueCode', 'Dim3 type',
#        'Dim3', 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource',
#        'FactValueNumericPrefix', 'FactValueNumeric', 'FactValueUoM',
#        'FactValueNumericLowPrefix', 'FactValueNumericLow',
#        'FactValueNumericHighPrefix', 'FactValueNumericHigh', 'Value',
#        'FactValueTranslationID', 'FactComments', 'Language', 'DateModified'],
#       dtype='object')

# %%
# Get a list of African countries from pycountry
african_countries = [country.name for country in pycountry.countries if country.alpha_2 in [
    'DZ', 'AO', 'BJ', 'BW', 'BF', 'BI', 'CM', 'CV', 'CF', 'TD', 'KM', 'CG', 'CD', 'DJ', 'EG', 'GQ', 'ER', 'ET', 
    'GA', 'GM', 'GH', 'GN', 'GW', 'KE', 'LS', 'LR', 'LY', 'MG', 'MW', 'ML', 'MR', 'MU', 'MA', 'MZ', 'NA', 'NE', 
    'NG', 'RW', 'ST', 'SN', 'SC', 'SL', 'SO', 'ZA', 'SS', 'SD', 'SZ', 'TZ', 'TG', 'TN', 'UG', 'ZM', 'ZW'
]]

# Filter rows for African countries
causes_of_death_africa = causes_of_death[causes_of_death['Location'].isin(african_countries)]
df8 = causes_of_death_africa
df8
# Out:
#        IndicatorCode                                          Indicator  \
# 47          MORT_300  Distribution of causes of death among children...
# 48          MORT_300  Distribution of causes of death among children...
# 49          MORT_300  Distribution of causes of death among children...
# 50          MORT_300  Distribution of causes of death among children...
# 51          MORT_300  Distribution of causes of death among children...
# ...              ...                                                ...
# 146634      MORT_300  Distribution of causes of death among children...
# 146646      MORT_300  Distribution of causes of death among children...
# 146650      MORT_300  Distribution of causes of death among children...
# 146652      MORT_300  Distribution of causes of death among children...
# 146657      MORT_300  Distribution of causes of death among children...
#
#        ValueType ParentLocationCode ParentLocation Location type  \
# ...

# %%
df8.describe()
# Out:
#              Period  Dim3 type  Dim3  Dim3ValueCode  DataSourceDimValueCode  \
# count  38556.000000        0.0   0.0            0.0                     0.0
# mean    2008.500000        NaN   NaN            NaN                     NaN
# std        5.188195        NaN   NaN            NaN                     NaN
# min     2000.000000        NaN   NaN            NaN                     NaN
# 25%     2004.000000        NaN   NaN            NaN                     NaN
# 50%     2008.500000        NaN   NaN            NaN                     NaN
# 75%     2013.000000        NaN   NaN            NaN                     NaN
# max     2017.000000        NaN   NaN            NaN                     NaN
#
#        DataSource  FactValueNumericPrefix  FactValueNumeric  FactValueUoM  \
# count         0.0                     0.0      38556.000000           0.0
# mean          NaN                     NaN          0.071425           NaN
# ...

# %%
# check for missing values
df8.isnull().sum()
# Out:
# IndicatorCode                     0
# Indicator                         0
# ValueType                         0
# ParentLocationCode                0
# ParentLocation                    0
# Location type                     0
# SpatialDimValueCode               0
# Location                          0
# Period type                       0
# Period                            0
# IsLatestYear                      0
# Dim1 type                         0
# Dim1                              0
# Dim1ValueCode                     0
# Dim2 type                         0
# Dim2                              0
# Dim2ValueCode                     0
# Dim3 type                     38556
# Dim3                          38556
# Dim3ValueCode                 38556
# DataSourceDimValueCode        38556
# DataSource                    38556
# FactValueNumericPrefix        38556
# FactValueNumeric                  0
# FactValueUoM                  38556
# FactValueNumericLowPrefix     38556
# ...

# %%
# drop column with NaN value
cleaned_df8 = df8.dropna(axis=1)
cleaned_df8
# Out:
#        IndicatorCode                                          Indicator  \
# 47          MORT_300  Distribution of causes of death among children...
# 48          MORT_300  Distribution of causes of death among children...
# 49          MORT_300  Distribution of causes of death among children...
# 50          MORT_300  Distribution of causes of death among children...
# 51          MORT_300  Distribution of causes of death among children...
# ...              ...                                                ...
# 146634      MORT_300  Distribution of causes of death among children...
# 146646      MORT_300  Distribution of causes of death among children...
# 146650      MORT_300  Distribution of causes of death among children...
# 146652      MORT_300  Distribution of causes of death among children...
# 146657      MORT_300  Distribution of causes of death among children...
#
#        ValueType ParentLocationCode ParentLocation Location type  \
# ...

# %%
cleaned_df8.describe()
# Out:
#              Period  FactValueNumeric         Value
# count  38556.000000      38556.000000  38556.000000
# mean    2008.500000          0.071425      0.067048
# std        5.188195          0.085061      0.091886
# min     2000.000000          0.000000      0.000000
# 25%     2004.000000          0.008000      0.000000
# 50%     2008.500000          0.041000      0.000000
# 75%     2013.000000          0.100000      0.100000
# max     2017.000000          0.760000      0.800000

# %%
# check for missing values
cleaned_df8.isnull().sum()
# Out:
# IndicatorCode          0
# Indicator              0
# ValueType              0
# ParentLocationCode     0
# ParentLocation         0
# Location type          0
# SpatialDimValueCode    0
# Location               0
# Period type            0
# Period                 0
# IsLatestYear           0
# Dim1 type              0
# Dim1                   0
# Dim1ValueCode          0
# Dim2 type              0
# Dim2                   0
# Dim2ValueCode          0
# FactValueNumeric       0
# Value                  0
# Language               0
# DateModified           0
# dtype: int64

# %%
# check for duplicate values
cleaned_df8.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Rename columns in df8 to match merged_data6 format
cleaned_df8.rename(columns={"Location": "Entity", "SpatialDimValueCode":  "Code", "Period": "Year"}, inplace=True)
# Out:
# C:\Users\My PC\AppData\Local\Temp\ipykernel_6188\3283550291.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df8.rename(columns={"Location": "Entity", "SpatialDimValueCode":  "Code", "Period": "Year"}, inplace=True)

# %%
cleaned_df8
# Out:
#        IndicatorCode                                          Indicator  \
# 47          MORT_300  Distribution of causes of death among children...
# 48          MORT_300  Distribution of causes of death among children...
# 49          MORT_300  Distribution of causes of death among children...
# 50          MORT_300  Distribution of causes of death among children...
# 51          MORT_300  Distribution of causes of death among children...
# ...              ...                                                ...
# 146634      MORT_300  Distribution of causes of death among children...
# 146646      MORT_300  Distribution of causes of death among children...
# 146650      MORT_300  Distribution of causes of death among children...
# 146652      MORT_300  Distribution of causes of death among children...
# 146657      MORT_300  Distribution of causes of death among children...
#
#        ValueType ParentLocationCode ParentLocation Location type Code  \
# ...

# %%
# Find the most common death causing disease
mode_Dim2 = cleaned_df8['Dim2'].mode()

print(f"Most common deadly diseases in African Countries are:\n {mode_Dim2.values}")
# Out:
# Most common deadly diseases in African Countries are:
#  ['Acute lower respiratory infections' 'Birth asphyxia and birth trauma'
#  'Congenital anomalies' 'Diarrhoeal diseases' 'HIV/AIDS' 'Injuries'
#  'Malaria' 'Measles' 'Meningitis/encephalitis'
#  'Other communicable, perinatal and nutritional conditions'
#  'Other noncommunicable diseases' 'Prematurity'
#  'Sepsis and other infectious conditions of the newborn' 'Tetanus']

# %%
print(cleaned_df8['Dim2'].mode())
# Out:
# 0                    Acute lower respiratory infections
# 1                       Birth asphyxia and birth trauma
# 2                                  Congenital anomalies
# 3                                   Diarrhoeal diseases
# 4                                              HIV/AIDS
# 5                                              Injuries
# 6                                               Malaria
# 7                                               Measles
# 8                               Meningitis/encephalitis
# 9     Other communicable, perinatal and nutritional ...
# 10                       Other noncommunicable diseases
# 11                                          Prematurity
# 12    Sepsis and other infectious conditions of the ...
# 13                                              Tetanus
# Name: Dim2, dtype: object

# %%
single_mode_Dim2 = cleaned_df8['Dim2'].mode()[0]
print(f"Most Common Deadly Disease in Africa: {single_mode_Dim2}")
# Out:
# Most Common Deadly Disease in Africa: Acute lower respiratory infections

# %%
# Frequecy of occurence in dataframe
count = cleaned_df8['Dim2'].value_counts().iloc[0]
print(f"Most Common Deadly Disease in Africa appears {count} times.")
# Out:
# Most Common Deadly Disease in Africa appears 2754 times.

# %%
# Merge datasets 'Vaccination Coverage' and 'Child mortality rate by country income level' for Analysis
merged_df1 = pd.merge(grouped_df2,grouped_df5, on=["Entity"], how = "inner")
# Display the merged dataset
merged_df1
# Out:
#                           BCG (% of one-year-olds immunized)  \
# Entity
# Algeria                                            96.390244
# Angola                                             56.666667
# Benin                                              83.810811
# Botswana                                           96.952381
# Burkina Faso                                       86.378378
# Burundi                                            84.243902
# Cameroon                                           72.682927
# Central African Republic                           63.785714
# Chad                                               46.717949
# Comoros                                            84.342105
# Congo                                              76.738095
# Djibouti                                           65.350000
# Egypt                                              88.619048
# Equatorial Guinea                                  76.918919
# ...

# %%
# Generate random colors for each data point
num_points = len(merged_df1)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df1["BCG (% of one-year-olds immunized)"], merged_df1["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Vaccination Coverage vs Child Mortality Rate by country level of income")
plt.xlabel("BCG (% of one-year-olds immunized)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Generate random colors for each data point
num_points = len(merged_df1)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df1["HepB3 (% of one-year-olds immunized)"], merged_df1["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Vaccination Coverage vs Child Mortality Rate by country level of income")
plt.xlabel("HepB3 (% of one-year-olds immunized)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Generate random colors for each data point
num_points = len(merged_df1)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df1["Hib3 (% of one-year-olds immunized)"], merged_df1["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Vaccination Coverage vs Child Mortality Rate by country level of income")
plt.xlabel("Hib3 (% of one-year-olds immunized)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Generate random colors for each data point
num_points = len(merged_df1)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df1["MCV1 (% of one-year-olds immunized)"], merged_df1["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Vaccination Coverage vs Child Mortality Rate by country level of income")
plt.xlabel("MCV1 (% of one-year-olds immunized)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Generate random colors for each data point
num_points = len(merged_df1)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df1["Pol3 (% of one-year-olds immunized)"], merged_df1["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Vaccination Coverage vs Child Mortality Rate by country level of income")
plt.xlabel("Pol3 (% of one-year-olds immunized)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Generate random colors for each data point
num_points = len(merged_df1)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df1["DTP3 (% of one-year-olds immunized)"], merged_df1["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Vaccination Coverage vs Child Mortality Rate by country level of income")
plt.xlabel("DTP3 (% of one-year-olds immunized)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Merge datasets 'Births attended by skilled health staff' and 'Child mortality rate by country income level' for Analysis
merged_df2 = pd.merge(grouped_df3,grouped_df5, on=["Entity"], how = "inner")

# Display the merged dataset
merged_df2
# Out:
#                           Births attended by skilled health staff (% of total)  \
# Entity
# Algeria                                                           92.500000
# Angola                                                            41.675000
# Benin                                                             74.971429
# Botswana                                                          96.390000
# Burkina Faso                                                      44.400000
# Burundi                                                           49.983333
# Cameroon                                                          61.200000
# Central African Republic                                          40.957143
# Chad                                                              20.016667
# Comoros                                                           65.200000
# Congo                                                             68.500000
# ...

# %%
_points = len(merged_df2)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df2["Births attended by skilled health staff (% of total)"], merged_df2["Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Births attended by skilled health staff (% of total) vs Child Mortality Rate by country level of income")
plt.xlabel("Births attended by skilled health staff (% of total)")
plt.ylabel("Child Mortality Rate by country level of income")

plt.show()

# %%
# Merge datasets Births attended by skilled health staff and infant deaths for Analysis
merged_df3 = pd.merge(grouped_df3,grouped_df6, on=["Entity"], how = "inner")
merged_df3
# Out:
#                           Births attended by skilled health staff (% of total)  \
# Entity
# Algeria                                                           92.500000
# Angola                                                            41.675000
# Benin                                                             74.971429
# Botswana                                                          96.390000
# Burkina Faso                                                      44.400000
# Burundi                                                           49.983333
# Cameroon                                                          61.200000
# Central African Republic                                          40.957143
# Chad                                                              20.016667
# Comoros                                                           65.200000
# Congo                                                             68.500000
# ...

# %%
_points = len(merged_df3)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df3["Deaths - Sex: all - Age: 0 - Variant: estimates"], merged_df3["Births attended by skilled health staff (% of total)"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Infant Deaths vs Births attended by skilled health staff")
plt.xlabel("Births attended by skilled health staff (% of total)")
plt.ylabel("Estimated Infant Deaths")

plt.show()

# %%
# Merge datasets Estimated maternal deaths and Births attended by skilled Health Staff for Analysis
merged_df4 = pd.merge(grouped_df3,grouped_df4, on=["Entity"], how = "inner")
merged_df4
# Out:
#                           Births attended by skilled health staff (% of total)  \
# Entity
# Algeria                                                           92.500000
# Angola                                                            41.675000
# Benin                                                             74.971429
# Botswana                                                          96.390000
# Burkina Faso                                                      44.400000
# Burundi                                                           49.983333
# Cameroon                                                          61.200000
# Central African Republic                                          40.957143
# Chad                                                              20.016667
# Comoros                                                           65.200000
# Congo                                                             68.500000
# ...

# %%
_points = len(merged_df4)
random_colors = np.random.rand(num_points, 3)  # Generates random RGB values between 0 and 1

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(merged_df4["Estimated maternal deaths"], merged_df4["Births attended by skilled health staff (% of total)"], 
            color=random_colors, s=100)  # s: size of points

# Add labels and title
plt.title("Estimated maternal deaths Vs Births attended by skilled health staff")
plt.xlabel("Births attended by skilled health staff (% of total)")
plt.ylabel("Estimated Maternal Deaths")

plt.show()

# %%
# Merge datasets Health Insurance Coverage and Youth Mortality Rate for Analysis
merged_df5 = pd.merge(df1,grouped_df7, on=["Entity"], how = "inner")
merged_df5.head(36)
# Out:
#                       Entity Code  \
# 0                    Algeria  DZA
# 1                     Angola  AGO
# 2                      Benin  BEN
# 3               Burkina Faso  BFA
# 4                    Burundi  BDI
# 5                   Cameroon  CMR
# 6   Central African Republic  CAF
# 7                   Djibouti  DJI
# 8                      Egypt  EGY
# 9                   Eswatini  SWZ
# 10                     Gabon  GAB
# 11                    Gambia  GMB
# 12                     Ghana  GHA
# 13                    Guinea  GIN
# 14             Guinea-Bissau  GNB
# 15                     Kenya  KEN
# 16                   Lesotho  LSO
# 17                Madagascar  MDG
# 18                      Mali  MLI
# 19                Mauritania  MRT
# 20                 Mauritius  MUS
# 21                   Morocco  MAR
# 22                   Namibia  NAM
# 23                     Niger  NER
# 24                   Nigeria  NGA
# 25                    Rwanda  RWA
# ...

# %%
sns.barplot(x='Share of population covered by health insurance (ILO (2014))', y='Under-fifteen mortality rate', data=merged_df5, palette='dark')
plt.title('Youth Mortality Rate vs. Health Insurance Coverage (% of population)')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\My PC\AppData\Local\Temp\ipykernel_6188\2675026188.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Share of population covered by health insurance (ILO (2014))', y='Under-fifteen mortality rate', data=merged_df5, palette='dark')

# %%
# Merge datasets (assuming common 'Entity'Columns)
# Merge datasets on multiple columns
merged_data1 = pd.merge(df1, grouped_df2, on=["Entity"], how = "inner")

# Display the merged dataset
merged_data1
# Out:
#                       Entity Code  \
# 0                    Algeria  DZA
# 1                     Angola  AGO
# 2                      Benin  BEN
# 3               Burkina Faso  BFA
# 4                    Burundi  BDI
# 5                   Cameroon  CMR
# 6   Central African Republic  CAF
# 7                   Djibouti  DJI
# 8                      Egypt  EGY
# 9                   Eswatini  SWZ
# 10                     Gabon  GAB
# 11                    Gambia  GMB
# 12                     Ghana  GHA
# 13                    Guinea  GIN
# 14             Guinea-Bissau  GNB
# 15                     Kenya  KEN
# 16                   Lesotho  LSO
# 17                Madagascar  MDG
# 18                      Mali  MLI
# 19                Mauritania  MRT
# 20                 Mauritius  MUS
# 21                   Morocco  MAR
# 22                   Namibia  NAM
# 23                     Niger  NER
# 24                   Nigeria  NGA
# 25                    Rwanda  RWA
# ...

# %%
# Merge datasets on multiple columns
merged_data2 = pd.merge(grouped_df3, grouped_df4, on=["Entity"], how = "inner")
merged_data2
# Out:
#                           Births attended by skilled health staff (% of total)  \
# Entity
# Algeria                                                           92.500000
# Angola                                                            41.675000
# Benin                                                             74.971429
# Botswana                                                          96.390000
# Burkina Faso                                                      44.400000
# Burundi                                                           49.983333
# Cameroon                                                          61.200000
# Central African Republic                                          40.957143
# Chad                                                              20.016667
# Comoros                                                           65.200000
# Congo                                                             68.500000
# ...

# %%
# Merge datasets on multiple columns
merged_data3 = pd.merge(grouped_df5, grouped_df6, on=["Entity"], how = "inner")

# Display the merged dataset
merged_data3
# Out:
#                           Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births  \
# Entity
# Algeria                                                           11.593816
# Angola                                                            16.985022
# Benin                                                             20.974372
# Botswana                                                           8.919949
# Burkina Faso                                                      24.095998
# Burundi                                                           16.478818
# Cameroon                                                          17.327769
# Central African Republic                                          17.816088
# Chad                                                              18.761423
# Comoros                                                           11.946566
# ...

# %%
# Merge datasets on multiple columns
merged_data4 = pd.merge(merged_data1, merged_data2, on=["Entity"], how = "inner")

# Display the merged dataset
merged_data4
# Out:
#                       Entity Code  \
# 0                    Algeria  DZA
# 1                     Angola  AGO
# 2                      Benin  BEN
# 3               Burkina Faso  BFA
# 4                    Burundi  BDI
# 5                   Cameroon  CMR
# 6   Central African Republic  CAF
# 7                   Djibouti  DJI
# 8                      Egypt  EGY
# 9                   Eswatini  SWZ
# 10                     Gabon  GAB
# 11                    Gambia  GMB
# 12                     Ghana  GHA
# 13                    Guinea  GIN
# 14             Guinea-Bissau  GNB
# 15                     Kenya  KEN
# 16                   Lesotho  LSO
# 17                Madagascar  MDG
# 18                      Mali  MLI
# 19                Mauritania  MRT
# 20                 Mauritius  MUS
# 21                   Morocco  MAR
# 22                   Namibia  NAM
# 23                     Niger  NER
# 24                   Nigeria  NGA
# 25                    Rwanda  RWA
# ...

# %%
# Merge datasets on multiple columns
merged_data5 = pd.merge(merged_data3, grouped_df7, on=["Entity"], how = "inner")

# Display the merged dataset
merged_data5
# Out:
#                           Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births  \
# Entity
# Algeria                                                           11.593816
# Angola                                                            16.985022
# Benin                                                             20.974372
# Botswana                                                           8.919949
# Burkina Faso                                                      24.095998
# Burundi                                                           16.478818
# Cameroon                                                          17.327769
# Central African Republic                                          17.816088
# Chad                                                              18.761423
# Comoros                                                           11.946566
# ...

# %%
# Merge datasets on multiple columns
merged_data6 = pd.merge(merged_data4, merged_data5, on=["Entity"], how = "inner")

# Display the merged dataset
merged_data6
# Out:
#                       Entity Code  \
# 0                    Algeria  DZA
# 1                     Angola  AGO
# 2                      Benin  BEN
# 3               Burkina Faso  BFA
# 4                    Burundi  BDI
# 5                   Cameroon  CMR
# 6   Central African Republic  CAF
# 7                   Djibouti  DJI
# 8                      Egypt  EGY
# 9                   Eswatini  SWZ
# 10                     Gabon  GAB
# 11                    Gambia  GMB
# 12                     Ghana  GHA
# 13                    Guinea  GIN
# 14             Guinea-Bissau  GNB
# 15                     Kenya  KEN
# 16                   Lesotho  LSO
# 17                Madagascar  MDG
# 18                      Mali  MLI
# 19                Mauritania  MRT
# 20                 Mauritius  MUS
# 21                   Morocco  MAR
# 22                   Namibia  NAM
# 23                     Niger  NER
# 24                   Nigeria  NGA
# 25                    Rwanda  RWA
# ...

# %%
# Merge datasets on multiple columns
merged_df = pd.merge(merged_data6, cleaned_df8, on=["Entity"], how = "inner")

# Display the overall merged dataset
merged_df
# Out:
#          Entity Code_x  \
# 0       Algeria    DZA
# 1       Algeria    DZA
# 2       Algeria    DZA
# 3       Algeria    DZA
# 4       Algeria    DZA
# ...         ...    ...
# 27211  Zimbabwe    ZWE
# 27212  Zimbabwe    ZWE
# 27213  Zimbabwe    ZWE
# 27214  Zimbabwe    ZWE
# 27215  Zimbabwe    ZWE
#
#        Share of population covered by health insurance (ILO (2014))  \
# 0                                                   85.2
# 1                                                   85.2
# 2                                                   85.2
# 3                                                   85.2
# 4                                                   85.2
# ...                                                  ...
# 27211                                                1.0
# 27212                                                1.0
# 27213                                                1.0
# 27214                                                1.0
# ...

# %%
# check for missing data
print("\nMissing Values:")
print(merged_df.isnull().sum())
# Out:
# Missing Values:
# Entity                                                                                                                                          0
# Code_x                                                                                                                                          0
# Share of population covered by health insurance (ILO (2014))                                                                                    0
# BCG (% of one-year-olds immunized)                                                                                                              0
# HepB3 (% of one-year-olds immunized)                                                                                                            0
# Hib3 (% of one-year-olds immunized)                                                                                                             0
# ...

# %%
merged_df.describe()
# Out:
#        Share of population covered by health insurance (ILO (2014))  \
# count                                       27216.000000
# mean                                           28.738889
# std                                            33.884331
# min                                             0.000000
# 25%                                             2.075000
# 50%                                             8.700000
# 75%                                            44.500000
# max                                           100.000000
#
#        BCG (% of one-year-olds immunized)  \
# count                        27216.000000
# mean                            81.350379
# std                             12.485413
# min                             50.609756
# 25%                             72.140244
# 50%                             86.037015
# 75%                             91.179464
# max                             96.390244
#
#        HepB3 (% of one-year-olds immunized)  \
# ...

# %%
# Getting numerical columns
num_cols = merged_df.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['Share of population covered by health insurance (ILO (2014))',
#        'BCG (% of one-year-olds immunized)',
#        'HepB3 (% of one-year-olds immunized)',
#        'Hib3 (% of one-year-olds immunized)',
#        'MCV1 (% of one-year-olds immunized)',
#        'Pol3 (% of one-year-olds immunized)',
#        'Pol3 (% of one-year-olds immunized).1',
#        'DTP3 (% of one-year-olds immunized)',
#        'Births attended by skilled health staff (% of total)',
#        'Estimated maternal deaths',
#        'Observation value - Indicator: Under-five mortality rate - Sex: Total - Wealth quintile: Total - Unit of measure: Deaths per 100 live births',
#        'Deaths - Sex: all - Age: 0 - Variant: estimates',
#        'Under-fifteen mortality rate', 'Year', 'FactValueNumeric', 'Value'],
#       dtype='object')

# %%
# Heatmap: Correlation between numeric features
correlation_matrix = merged_df[num_cols].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()
